# %% [markdown]
# <a href="https://colab.research.google.com/github/JoaoIto/Sistemas-De-Informacao/blob/main/an%C3%A1lise_dataset_alunos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análise de DataSet de Alunos

# %% [markdown]
# - Temos um arquivos de dados alunos para podermos analisar;

# %%
import pandas as pd

# %% [markdown]
# - Usaremos o pandas para essa análise
# - Carregando DataFrame:

# %%
df = pd.read_csv('dados_alunos.csv')

# %% [markdown]
# - Exibir as linhas iniciais do DataFrame

# %%
df.head()
# Out:
#        Nome  Idade  Nota       Curso
# 0     Júlia     29  6.99     Direito
# 1       Ana     19  9.08    Medicina
# 2    Felipe     18  8.99    Medicina
# 3  Fernanda     33  5.75    Medicina
# 4     Júlia     22  7.54  Engenharia

# %% [markdown]
# - Exibir linhas finais do DataFrame

# %%
df.tail()
# Out:
#        Nome  Idade  Nota                  Curso
# 95  Ricardo     23  9.65          Administração
# 96    Paula     22  5.35               Medicina
# 97    Júlia     37  6.04                Direito
# 98    Paula     19  8.36  Ciência da Computação
# 99   Felipe     23  6.79               Economia
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Idade'].plot(kind='hist', bins=20, title='Idade')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Nota'].plot(kind='hist', bins=20, title='Nota')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %% [markdown]
# - Tamanho do Dataset

# %%
df.shape
# Out:
# (100, 4)

# %% [markdown]
# Filtrar alunos com menos de 20 anos
